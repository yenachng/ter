# %%
import networkx as nx
import numpy as np
from scipy.linalg import eigvals, eigh
from scipy.sparse.linalg import eigsh
from sklearn.decomposition import PCA
from collections import deque
from sklearn.cluster import KMeans

# %%
def prelim_tr(G):
    leaves = [node for node in G.nodes if G.degree(node)==1]
    if len(leaves)>2:
        print("too many leaves,", leaves)
        return None
    H= G.copy()
    queue = deque([node for node in H.nodes() if H.degree(node)==2])
    in_queue = set(queue)
    
    while queue:
        node = queue.popleft()
        in_queue.discard(node)
        
        if node not in H or H.degree(node)!=2:
            continue
            
        u,w = list(H.neighbors(node))
        H.remove_node(node)
        
        if u!=w and not H.has_edge(u,w):
            H.add_edge(u,w)
            
        for n in (u,w):
            if H.has_node(n) and H.degree(n)==2 and n not in in_queue:
                queue.append(n)
                in_queue.add(n)
    return H

# %%
def adj_et_deg(G):
    A = nx.to_numpy_array(G)
    degrees = np.sum(A, axis=1)
    return A, degrees

def laplacian_et_signless(A, D):
    L = D-A
    Q = D+A
    return L, Q

# %%
def signless_laplacian_rad(Q):
    q_eigs = np.sort(np.real(eigvals(Q)))[::-1]
    q_spectral_radius = q_eigs[0]
    return q_spectral_radius

# %%
def fiedler_vect(G):
    L = nx.laplacian_matrix(G).astype(float)
    eigvals, eigvects = eigsh(L, k=2, which='SM')
    
    idx = np.argsort(eigvals)
    
    fiedler_vect = eigvects[:,idx[1]]
    return fiedler_vect

# %%
def fiedler_sort(G):
    fvect = fiedler_vect(G)
    nodes = list(G.nodes)
    fdict = {node: val for node, val in zip(nodes, fvect)}
    sorted_tup = sorted(fdict.items(), key=lambda x: x[1])
    return sorted_tup

# %%
def gap_threshold(sorted_fiedler, factor):
    gaps = np.diff([t[1] for t in sorted_fiedler])
    median_gap = np.median(gaps)
    std_gap = np.std(gaps)
    exclude_outliers = gaps[gaps <= median_gap+factor*std_gap]
    
    if len(exclude_outliers)==0:
        return gaps, np.mean(gaps)
    threshold = np.mean(exclude_outliers)
    
    #check prints
    print("median gap:", median_gap)
    print("mean gap:", threshold)
    print("number of regular gaps", len(exclude_outliers))
    print("number of irregular gaps", len(gaps)-len(exclude_outliers))
    
    return gaps, threshold

# %%
def eigengap_k(eigenvals):# maybe add max nbr candidates in case 98239824u28u98u eigenvals
    gaps = np.diff(eigenvals)
    k = np.argmax(gaps)+1
    other_gaps = np.delete(gaps, k)
    
    if len(other_gaps)>0:
        median_gap = np.median(other_gaps)
        mean_gap = np.mean(other_gaps)
        std_gap = np.std(other_gaps)
    else:
        median_gap=0
        mean_gap = 0
        std_gap = 1
    ratio = k/median_gap if median_gap>0 else np.inf
    z_score = (k- mean_gap)/std_gap
    
    return k, ratio, z_score

# %%
def Q_eigengap(eigenvals):
    gaps = np.diff(eigenvals)

# %%
# tolerance on multiplicity

# %%
def spectral_embedding(G, n_ev):
    A, degrees = adj_et_deg(G)
    D = np.diag(degrees)
    L, Q = laplacian_et_signless(A,D)
    eigenvals_L, eigenvecs_L = eigh(L)
    embedding = eigenvecs_L[:,1:n_ev+1]
    return embedding, eigenvals_L[1:n_ev+1]

# %%
def signless_spectral_embedding(G, n_e):
    A, degrees = adj_et_deg(G)
    D = np.diag(degrees)
    L, Q = laplacian_et_signless(A,D)
    eigenvals_Q, eigenvecs_Q = eigsh(Q, k=n_e, which='LA')
    idx = np.argsort(eigenvals_Q)[::-1]
    eigenvals_Q = eigenvals_Q[idx]
    eigenvecs_Q = eigenvecs_Q[:, idx]
    return eigenvals, eigenvecs

# %%
def weighted_signless_fingerprint(G, n_e):
    eigenvals, eigenvecs = signless_spectral_embedding(G,n_e)
    fingerprint = {}
    total_weight = np.sum(eigenvals)
    for i in range(n_components):

# %%
def pca_reduce(embedding, variance_threshold=0.9):
    pca = PCA()
    full_transformed = pca.fit_transform(embedding)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    n_components = np.searchsorted(cumulative_variance, variance_threshold) + 1
    reduced_embedding = full_transformed[:, :n_components]
    return reduced_embedding, n_components, cumulative_variance

# %%
def choose_embedding_and_cluster_method(G, n_ev, clear_gap_threshold=2.0, variance_threshold=0.9):
    embedding, eigenvals = spectral_embedding(G, n_ev)
    k, ratio, z_score = eigengap_k(eigenvals)
    print(f"eigengap: k = {k}, ratio = {ratio}, z_score = {z_score}")
    
    if ratio < clear_gap_threshold and z_score < clear_gap_threshold:
        print("eigengap not clear enough; applying PCA.")
        final_embedding, chosen_dim, cum_var = pca_reduce(embedding, variance_threshold)
        method = 'pca'
    else:
        final_embedding = embedding[:, :k]
        chosen_dim = k
        method = 'eigengap'
    
    print(f"Final embedding dimension: {chosen_dim}")
    return final_embedding, chosen_dim, k, ratio, z_score, method

# %%
def signless_embedding(G, cluster_embed):
    A, degrees = adj_et_deg(G)
    D_sqrt_inv = np.diag(1/np.sqrt(np.where(degrees==0, 1e-10, degrees)))
    Q_norm = D_sqrt_inv @ Q @ D_sqrt_inv
    Qr, eigenvals_Qn = signless_laplacian_rad(Q_norm)
    
    augmented_embedding = np.hstack([cluster_embed, Qr])
    return augmented_embedding

# %%
def partition_by_gap(G):
    sortedtup = fiedler_sort(G)
    factor = 1
    gaps, threshold = gap_threshold(sortedtup, factor)
    nodes = list(G.nodes())
    
    balls = []
    current_ball = {'vertices':[sortedtup[:][0]],
                    'fiedler values': [sortedtup[:][1]],
    }
    
    for i in range(1, len(sortedtup)):
        if sortedtup[i][1]-sortedtup[i-1][1] > threshold:
            current_ball['size'] = len(current_ball['vertices'])
            current_ball['density'] = 1 #if low cost then just run spectral conds
            balls.append(current_ball)
            current_ball = {'vertices': [], 'fiedler_vals':[]}
        current_ball['vertices'].append(sortedtup[i][0])
        current_ball['fiedler_vals'].append(sortedtup[i][1])
    if current_ball:
        current_ball['size'] = len(current_ball['vertices'])
        current_ball['density'] = 1
        balls.append(current_ball)
    return balls

# %%
def ball_edge(ball1, ball2, G):
    edges = []
    for u in ball1['vertices']:
        for v in ball2['vertices']:
            if G.has_edge(u,v):
                edges.append((u,v))
                return True
    return False

# %%
def build_ball_graph(balls, G):
    BG = nx.Graph()
    for i, ball in enumerate(balls):
        BG.add_node(i, ball=ball, importance=['density'])
    for i in range(n):
        for j in range(i+1,n):
            if ball_edge(balls[i], balls[j], G):
                BG.add_edge(i,j)
    return BG

# %%
import random
from graph_loader import load_all_graphs

folder = 'test_data'
graphs = load_all_graphs(folder)
G = prelim_tr(random.choice(list(graphs.values())))

# %%
embedding = spectral_embedding(G, 10)

final_embedding, chosen_dim, k_val, gap_ratio, gap_zscore, method = choose_embedding_and_cluster_method(G, n_ev=10, clear_gap_threshold=2.0, variance_threshold=0.9)
    
print("Chosen method:", method)
print("Final embedding shape:", final_embedding.shape)
# Out:
# original embedding shape: (1998, 10)
# original embedding shape: (1998, 10)
# eigengap: k = 1, ratio = 314.4290763861398, z_score = 263.15032461003824
# Final embedding dimension: 1
# Chosen method: eigengap
# Final embedding shape: (1998, 1)

# %%
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
clustering(final_embedding, k_val, method)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
partition_by_gap(G)
# Out:
# median gap: 1.4736257084486297e-05
# mean gap: 2.6588473033270144e-05
# number of regular gaps 2920
# number of irregular gaps 79
# [{'vertices': [(2661, -0.0976397188390776)],
#   'fiedler values': [(1749, -0.09576830507161635)],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1749],
#   'fiedler_vals': [-0.09576830507161635],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2677],
#   'fiedler_vals': [-0.09242385349848124],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2675],
#   'fiedler_vals': [-0.0910088933252773],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2660],
#   'fiedler_vals': [-0.09090003447637143],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1756],
#   'fiedler_vals': [-0.08910639141707609],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2678],
#   'fiedler_vals': [-0.08735252881053773],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2674],
#   'fiedler_vals': [-0.08428891196438829],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2676],
#   'fiedler_vals': [-0.08353106875133497],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1754],
#   'fiedler_vals': [-0.0791135303033747],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2523],
#   'fiedler_vals': [-0.07178554475246289],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2524],
#   'fiedler_vals': [-0.07117460001006552],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2133],
#   'fiedler_vals': [-0.07046205893661259],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2659],
#   'fiedler_vals': [-0.0692555208218816],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2134],
#   'fiedler_vals': [-0.06881675184068567],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2673],
#   'fiedler_vals': [-0.06674939775695796],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1541],
#   'fiedler_vals': [-0.06656901374667816],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2135],
#   'fiedler_vals': [-0.06315532140921912],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1755],
#   'fiedler_vals': [-0.06293562731980085],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2498],
#   'fiedler_vals': [-0.06255927546613854],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1709],
#   'fiedler_vals': [-0.06246871748989409],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2505],
#   'fiedler_vals': [-0.060534764114619825],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2499],
#   'fiedler_vals': [-0.059462771940605993],
#   'size': 1,
#   'density': 1},
#  {'vertices': [647],
#   'fiedler_vals': [-0.05917209922305865],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1540],
#   'fiedler_vals': [-0.058158685602523755],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1445],
#   'fiedler_vals': [-0.057826905666963434],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1493],
#   'fiedler_vals': [-0.05616051672787756],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2977],
#   'fiedler_vals': [-0.0561061361623164],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2240],
#   'fiedler_vals': [-0.05573082918412677],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2672],
#   'fiedler_vals': [-0.05557150674903058],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2525, 2971],
#   'fiedler_vals': [-0.055214733567906536, -0.05520360293874658],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2497],
#   'fiedler_vals': [-0.054945822167279],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1440],
#   'fiedler_vals': [-0.0547730131054815],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2016],
#   'fiedler_vals': [-0.05263279321720588],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1877],
#   'fiedler_vals': [-0.05209280723258783],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1753],
#   'fiedler_vals': [-0.05186726225208919],
#   'size': 1,
#   'density': 1},
#  {'vertices': [528],
#   'fiedler_vals': [-0.05141456129889539],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2668],
#   'fiedler_vals': [-0.050852664907963384],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2986],
#   'fiedler_vals': [-0.05082366320100276],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2671],
#   'fiedler_vals': [-0.050185042835846884],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2504],
#   'fiedler_vals': [-0.050147543862812546],
#   'size': 1,
#   'density': 1},
#  {'vertices': [725],
#   'fiedler_vals': [-0.050010132215749604],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2665],
#   'fiedler_vals': [-0.04958663186083673],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1357],
#   'fiedler_vals': [-0.04954836071422397],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2985],
#   'fiedler_vals': [-0.04878869183934511],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2978],
#   'fiedler_vals': [-0.048618264583868726],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1583],
#   'fiedler_vals': [-0.047249478028743366],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2586],
#   'fiedler_vals': [-0.04708449820189392],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2139],
#   'fiedler_vals': [-0.04696365127261692],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1586],
#   'fiedler_vals': [-0.046736225360647206],
#   'size': 1,
#   'density': 1},
#  {'vertices': [569],
#   'fiedler_vals': [-0.046330170520594446],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1729],
#   'fiedler_vals': [-0.046111167717766605],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1419],
#   'fiedler_vals': [-0.04584784090335658],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2989, 1467],
#   'fiedler_vals': [-0.04574741609694167, -0.04574680082360865],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2972],
#   'fiedler_vals': [-0.045515077967298714],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1584],
#   'fiedler_vals': [-0.04545307732961581],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1546],
#   'fiedler_vals': [-0.045376619409961454],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2976],
#   'fiedler_vals': [-0.04458687937967231],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1182],
#   'fiedler_vals': [-0.04415793104352429],
#   'size': 1,
#   'density': 1},
#  {'vertices': [438],
#   'fiedler_vals': [-0.04406105803579507],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2015],
#   'fiedler_vals': [-0.043811842776992974],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2669],
#   'fiedler_vals': [-0.04359247738771189],
#   'size': 1,
#   'density': 1},
#  {'vertices': [877],
#   'fiedler_vals': [-0.043501101305947525],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2984],
#   'fiedler_vals': [-0.04275036996160247],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2331],
#   'fiedler_vals': [-0.042436016246682],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1751],
#   'fiedler_vals': [-0.04209967937007668],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2990],
#   'fiedler_vals': [-0.04185132357448157],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1330],
#   'fiedler_vals': [-0.041670137634895126],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2526],
#   'fiedler_vals': [-0.041372500526289206],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1608],
#   'fiedler_vals': [-0.04117560350667616],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2522],
#   'fiedler_vals': [-0.040786209317716315],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1926],
#   'fiedler_vals': [-0.04041482991886043],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2140],
#   'fiedler_vals': [-0.040257791327726215],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2988],
#   'fiedler_vals': [-0.040157428352339264],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2987],
#   'fiedler_vals': [-0.040127424095595214],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2947],
#   'fiedler_vals': [-0.0399370200508642],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2664],
#   'fiedler_vals': [-0.039747759030196186],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1649],
#   'fiedler_vals': [-0.039520884270781896],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1051, 2667],
#   'fiedler_vals': [-0.039013365630104276, -0.0389936931966128],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2400],
#   'fiedler_vals': [-0.038695683250463644],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2330],
#   'fiedler_vals': [-0.03861290465699181],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2913],
#   'fiedler_vals': [-0.038450222141027966],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1677, 1878],
#   'fiedler_vals': [-0.038323832042315646, -0.038316563530498865],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2494],
#   'fiedler_vals': [-0.038095640798974845],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1831],
#   'fiedler_vals': [-0.03799866651588227],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2915, 1256],
#   'fiedler_vals': [-0.03795764154618313, -0.03793599798717862],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2401],
#   'fiedler_vals': [-0.037881779773272395],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1750, 2164],
#   'fiedler_vals': [-0.03782682251502959, -0.03782637142382372],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1443],
#   'fiedler_vals': [-0.03778493250057009],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1542],
#   'fiedler_vals': [-0.03774576543896838],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1429, 826],
#   'fiedler_vals': [-0.037545127238331026, -0.03752908894741801],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1706],
#   'fiedler_vals': [-0.03748174913050011],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2582],
#   'fiedler_vals': [-0.037424504751143874],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2487, 2670, 1618, 2410],
#   'fiedler_vals': [-0.03703597319366632,
#    -0.03703573784800889,
#    -0.03701972250151591,
#    -0.03701327965343606],
#   'size': 4,
#   'density': 1},
#  {'vertices': [635],
#   'fiedler_vals': [-0.036835243871002635],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2226],
#   'fiedler_vals': [-0.03661782878798934],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1052],
#   'fiedler_vals': [-0.03649570093375585],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1927],
#   'fiedler_vals': [-0.03646898692886024],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1047],
#   'fiedler_vals': [-0.03619927896222374],
#   'size': 1,
#   'density': 1},
#  {'vertices': [608],
#   'fiedler_vals': [-0.0359344454636296],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1748],
#   'fiedler_vals': [-0.03588457089037314],
#   'size': 1,
#   'density': 1},
#  {'vertices': [734, 2489, 2666],
#   'fiedler_vals': [-0.035714488232711464,
#    -0.03571060349801463,
#    -0.03570974540898857],
#   'size': 3,
#   'density': 1},
#  {'vertices': [506, 765],
#   'fiedler_vals': [-0.035307313408925935, -0.035293305435233506],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1728],
#   'fiedler_vals': [-0.03523362053030788],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1379, 1045],
#   'fiedler_vals': [-0.03513965083507052, -0.03511903544835724],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2227],
#   'fiedler_vals': [-0.035081042349780746],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1358],
#   'fiedler_vals': [-0.03466073564054321],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2459],
#   'fiedler_vals': [-0.034583949016194035],
#   'size': 1,
#   'density': 1},
#  {'vertices': [683],
#   'fiedler_vals': [-0.03451235273043719],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1594],
#   'fiedler_vals': [-0.03434343018444527],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2488],
#   'fiedler_vals': [-0.03424610128011061],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1092],
#   'fiedler_vals': [-0.033647174697504195],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1444],
#   'fiedler_vals': [-0.033389472725359595],
#   'size': 1,
#   'density': 1},
#  {'vertices': [449],
#   'fiedler_vals': [-0.03329450165736057],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1593],
#   'fiedler_vals': [-0.03326761010211183],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2906],
#   'fiedler_vals': [-0.03317787697010801],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2973],
#   'fiedler_vals': [-0.03305813901079513],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1356, 1817],
#   'fiedler_vals': [-0.03295503844180063, -0.032952321661889904],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1240],
#   'fiedler_vals': [-0.03279236315057593],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2031],
#   'fiedler_vals': [-0.032743971940215],
#   'size': 1,
#   'density': 1},
#  {'vertices': [127],
#   'fiedler_vals': [-0.03269791697717545],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1185],
#   'fiedler_vals': [-0.03264888185347829],
#   'size': 1,
#   'density': 1},
#  {'vertices': [626],
#   'fiedler_vals': [-0.03230398430487589],
#   'size': 1,
#   'density': 1},
#  {'vertices': [294],
#   'fiedler_vals': [-0.0322023789749894],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2917],
#   'fiedler_vals': [-0.03203771870732908],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2241],
#   'fiedler_vals': [-0.0319752818182169],
#   'size': 1,
#   'density': 1},
#  {'vertices': [126],
#   'fiedler_vals': [-0.03179221103902416],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1704],
#   'fiedler_vals': [-0.03176454505189256],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2332, 2578],
#   'fiedler_vals': [-0.03169135849986278, -0.03167405285727896],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2916],
#   'fiedler_vals': [-0.03162179336011892],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2781, 1208, 1265, 520, 2974],
#   'fiedler_vals': [-0.031484418853641075,
#    -0.03146608925886282,
#    -0.03145682773227238,
#    -0.03145514098361668,
#    -0.031448399453515276],
#   'size': 5,
#   'density': 1},
#  {'vertices': [1046],
#   'fiedler_vals': [-0.031370870708041156],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2239, 1513, 1714],
#   'fiedler_vals': [-0.031236453572877153,
#    -0.03121711926422782,
#    -0.03120198038139395],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1579],
#   'fiedler_vals': [-0.03117465902126424],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2083, 585, 1333, 2114],
#   'fiedler_vals': [-0.03110830600803699,
#    -0.031087191196389998,
#    -0.03106653188512915,
#    -0.03105003358906022],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2583],
#   'fiedler_vals': [-0.0309352692708854],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1257],
#   'fiedler_vals': [-0.030812346292258413],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2914],
#   'fiedler_vals': [-0.030661812431206227],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1310],
#   'fiedler_vals': [-0.030502504899635484],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1340],
#   'fiedler_vals': [-0.030373394577408643],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1399, 1710],
#   'fiedler_vals': [-0.030263131613014766, -0.030253638041949932],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2496],
#   'fiedler_vals': [-0.03019684293034033],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2084],
#   'fiedler_vals': [-0.030168217939283797],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1788],
#   'fiedler_vals': [-0.029941035334834307],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1090],
#   'fiedler_vals': [-0.029720460972321307],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2912],
#   'fiedler_vals': [-0.029670141782730388],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2399],
#   'fiedler_vals': [-0.0295812538472817],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1316],
#   'fiedler_vals': [-0.029295542696583722],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2975],
#   'fiedler_vals': [-0.029260604719645644],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2946],
#   'fiedler_vals': [-0.029172425001090057],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1345],
#   'fiedler_vals': [-0.02908972990856661],
#   'size': 1,
#   'density': 1},
#  {'vertices': [209],
#   'fiedler_vals': [-0.02903958141610468],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1504],
#   'fiedler_vals': [-0.02895899452886379],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1255, 2789],
#   'fiedler_vals': [-0.028909915010795782, -0.02890088079987826],
#   'size': 2,
#   'density': 1},
#  {'vertices': [758],
#   'fiedler_vals': [-0.0288400194641258],
#   'size': 1,
#   'density': 1},
#  {'vertices': [586],
#   'fiedler_vals': [-0.028772684980906908],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2201],
#   'fiedler_vals': [-0.02863698386756112],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2082],
#   'fiedler_vals': [-0.028525616144872295],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1974, 1375],
#   'fiedler_vals': [-0.02831252405633746, -0.028298438195524946],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1707],
#   'fiedler_vals': [-0.028242510571846582],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2132],
#   'fiedler_vals': [-0.028109346208265242],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1087],
#   'fiedler_vals': [-0.02787417122968095],
#   'size': 1,
#   'density': 1},
#  {'vertices': [684],
#   'fiedler_vals': [-0.027814398980962877],
#   'size': 1,
#   'density': 1},
#  {'vertices': [207],
#   'fiedler_vals': [-0.027762881562330158],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2585],
#   'fiedler_vals': [-0.02754122076419818],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2112],
#   'fiedler_vals': [-0.027411848844183292],
#   'size': 1,
#   'density': 1},
#  {'vertices': [827],
#   'fiedler_vals': [-0.02730227068720459],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2663, 1516, 711, 675],
#   'fiedler_vals': [-0.027168915375726993,
#    -0.027166915595718124,
#    -0.02716526793907052,
#    -0.027155449155388065],
#   'size': 4,
#   'density': 1},
#  {'vertices': [1417, 321, 2297, 2225],
#   'fiedler_vals': [-0.02706633452427672,
#    -0.02706352440730507,
#    -0.027047769481409814,
#    -0.02702808160444729],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2086, 410],
#   'fiedler_vals': [-0.026928881236110293, -0.026903522967906622],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2145, 2842],
#   'fiedler_vals': [-0.026792412282251817, -0.026766011331557878],
#   'size': 2,
#   'density': 1},
#  {'vertices': [224],
#   'fiedler_vals': [-0.026685784197933177],
#   'size': 1,
#   'density': 1},
#  {'vertices': [615],
#   'fiedler_vals': [-0.02658237139507679],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1266],
#   'fiedler_vals': [-0.02653545048089052],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2220, 2141, 2165],
#   'fiedler_vals': [-0.026490334388525435,
#    -0.026471227928899593,
#    -0.026462709813560983],
#   'size': 3,
#   'density': 1},
#  {'vertices': [65, 682],
#   'fiedler_vals': [-0.026248399186420596, -0.026242354671302107],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1928, 182, 1752],
#   'fiedler_vals': [-0.026153608412358052,
#    -0.026144564782475902,
#    -0.02614008702718689],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2158, 1222],
#   'fiedler_vals': [-0.02610786862462865, -0.026084033175101082],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2580, 2701, 1569, 1791],
#   'fiedler_vals': [-0.025948054800263357,
#    -0.0259216128619063,
#    -0.02591407944229226,
#    -0.025911657636298765],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2027],
#   'fiedler_vals': [-0.025775520468315164],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2125],
#   'fiedler_vals': [-0.025734312006886587],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2028],
#   'fiedler_vals': [-0.025636629942457113],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2830, 2840],
#   'fiedler_vals': [-0.02558619321712444, -0.02558143061774098],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2790],
#   'fiedler_vals': [-0.025542242396615338],
#   'size': 1,
#   'density': 1},
#  {'vertices': [475],
#   'fiedler_vals': [-0.025515640642321313],
#   'size': 1,
#   'density': 1},
#  {'vertices': [664, 2829],
#   'fiedler_vals': [-0.02540397353017578, -0.02539722894855786],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1074, 460],
#   'fiedler_vals': [-0.025344547777777546, -0.025336708990689003],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2312],
#   'fiedler_vals': [-0.02515703097015054],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2970],
#   'fiedler_vals': [-0.025112129963512312],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1138],
#   'fiedler_vals': [-0.025056208363494984],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1053, 2246, 1807, 766],
#   'fiedler_vals': [-0.02499108889502323,
#    -0.024972763933162494,
#    -0.024951601507492847,
#    -0.024933732776493092],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2581, 462, 1994],
#   'fiedler_vals': [-0.02489850009503242,
#    -0.024877019453229707,
#    -0.02486317817953931],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2831],
#   'fiedler_vals': [-0.02482233635182128],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1757],
#   'fiedler_vals': [-0.024771305961404762],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2962, 1364, 1552],
#   'fiedler_vals': [-0.02472109053272541,
#    -0.024706320238562725,
#    -0.024684466472121837],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2832, 1225, 2126, 2030, 2085],
#   'fiedler_vals': [-0.024646007178710492,
#    -0.024619685303459458,
#    -0.024616363855819008,
#    -0.024595329473536334,
#    -0.024588899581701906],
#   'size': 5,
#   'density': 1},
#  {'vertices': [1428],
#   'fiedler_vals': [-0.024449174374787108],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2577],
#   'fiedler_vals': [-0.024299985539161476],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2018],
#   'fiedler_vals': [-0.024208698515957604],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2402],
#   'fiedler_vals': [-0.024144996068576837],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1578],
#   'fiedler_vals': [-0.024084870934622294],
#   'size': 1,
#   'density': 1},
#  {'vertices': [962],
#   'fiedler_vals': [-0.0240210243180295],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2503],
#   'fiedler_vals': [-0.023923814525743055],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2411],
#   'fiedler_vals': [-0.023880431628706213],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2617],
#   'fiedler_vals': [-0.023844559470772176],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1973],
#   'fiedler_vals': [-0.023712575984308586],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2342],
#   'fiedler_vals': [-0.023633881457280605],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1922],
#   'fiedler_vals': [-0.02356639857024135],
#   'size': 1,
#   'density': 1},
#  {'vertices': [621],
#   'fiedler_vals': [-0.023492343430362737],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2024],
#   'fiedler_vals': [-0.02345947306353066],
#   'size': 1,
#   'density': 1},
#  {'vertices': [208],
#   'fiedler_vals': [-0.023402493115015296],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2841],
#   'fiedler_vals': [-0.02337472414457787],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1633, 1337],
#   'fiedler_vals': [-0.023335077396096034, -0.02331454366572743],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2025, 2500],
#   'fiedler_vals': [-0.023247905238685848, -0.023247727911510363],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2032],
#   'fiedler_vals': [-0.02321655115139595],
#   'size': 1,
#   'density': 1},
#  {'vertices': [195],
#   'fiedler_vals': [-0.023181553913389222],
#   'size': 1,
#   'density': 1},
#  {'vertices': [918],
#   'fiedler_vals': [-0.02312191132314249],
#   'size': 1,
#   'density': 1},
#  {'vertices': [769, 1029, 2014, 2983],
#   'fiedler_vals': [-0.023066587884739906,
#    -0.023047355960191352,
#    -0.023037981258357883,
#    -0.023018633186103362],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2460, 2111],
#   'fiedler_vals': [-0.022958396427911622, -0.022944229627231336],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2228, 2782, 236],
#   'fiedler_vals': [-0.022915064990406516,
#    -0.022903427368527067,
#    -0.022901005898252832],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2406, 1970],
#   'fiedler_vals': [-0.022870781365901077, -0.022848874794119435],
#   'size': 2,
#   'density': 1},
#  {'vertices': [373, 1931, 1303, 2329, 2087],
#   'fiedler_vals': [-0.022800562246949586,
#    -0.02279605392450847,
#    -0.02278389385984677,
#    -0.022781486653883524,
#    -0.02277507178638338],
#   'size': 5,
#   'density': 1},
#  {'vertices': [1613],
#   'fiedler_vals': [-0.022717571291714242],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1460, 1242],
#   'fiedler_vals': [-0.022644517601073704, -0.022627888075953558],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2219],
#   'fiedler_vals': [-0.022387773584091705],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1816],
#   'fiedler_vals': [-0.022265418344890636],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2238],
#   'fiedler_vals': [-0.02223525619778918],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2343],
#   'fiedler_vals': [-0.022191931940549258],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1441, 2493, 1485],
#   'fiedler_vals': [-0.022092823209886467,
#    -0.022085681504078046,
#    -0.02208482176540217],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2833, 1306],
#   'fiedler_vals': [-0.022025344083389728, -0.02202103730959121],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1638, 1183, 693],
#   'fiedler_vals': [-0.021862350271030763,
#    -0.021852360708865023,
#    -0.02182859770408755],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2398],
#   'fiedler_vals': [-0.021781361080661837],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2231],
#   'fiedler_vals': [-0.021714149140045883],
#   'size': 1,
#   'density': 1},
#  {'vertices': [610, 1617, 1249],
#   'fiedler_vals': [-0.021683113949749457,
#    -0.02166265856207707,
#    -0.02165412469248852],
#   'size': 3,
#   'density': 1},
#  {'vertices': [539, 277],
#   'fiedler_vals': [-0.02159724254933596, -0.021589701083774525],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2213, 371],
#   'fiedler_vals': [-0.021483595885994876, -0.021464490429913854],
#   'size': 2,
#   'density': 1},
#  {'vertices': [235, 723],
#   'fiedler_vals': [-0.021392127753497445, -0.021370509548908387],
#   'size': 2,
#   'density': 1},
#  {'vertices': [971],
#   'fiedler_vals': [-0.021338284711707147],
#   'size': 1,
#   'density': 1},
#  {'vertices': [606],
#   'fiedler_vals': [-0.021306063432118324],
#   'size': 1,
#   'density': 1},
#  {'vertices': [710, 1693],
#   'fiedler_vals': [-0.021271256697598023, -0.02125808914391019],
#   'size': 2,
#   'density': 1},
#  {'vertices': [915, 2113, 1891],
#   'fiedler_vals': [-0.02116586425332278,
#    -0.0211438518225186,
#    -0.021139963859566596],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1024],
#   'fiedler_vals': [-0.02108621266724044],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1591, 2230],
#   'fiedler_vals': [-0.020977304841582844, -0.020963755398622],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1366],
#   'fiedler_vals': [-0.020927454907788464],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1498, 1162, 137, 2340],
#   'fiedler_vals': [-0.0208843739957741,
#    -0.02088239184347898,
#    -0.02086604746177771,
#    -0.02086053295575014],
#   'size': 4,
#   'density': 1},
#  {'vertices': [1093],
#   'fiedler_vals': [-0.020761644613939735],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1811],
#   'fiedler_vals': [-0.020725121621198515],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2443],
#   'fiedler_vals': [-0.020669927869803647],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1983],
#   'fiedler_vals': [-0.020594917923626443],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1423, 1147, 1892, 641],
#   'fiedler_vals': [-0.020482484935346348,
#    -0.02046890540751789,
#    -0.02045505536418915,
#    -0.020447708529883552],
#   'size': 4,
#   'density': 1},
#  {'vertices': [975, 2501],
#   'fiedler_vals': [-0.020356941030877145, -0.020351939233657766],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2065],
#   'fiedler_vals': [-0.020298884855034824],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2212],
#   'fiedler_vals': [-0.02022114665895358],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1889, 467, 2934, 2961],
#   'fiedler_vals': [-0.02016864707448642,
#    -0.02015597742155753,
#    -0.020153821252384706,
#    -0.02014301102868925],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2221],
#   'fiedler_vals': [-0.020088673335844628],
#   'size': 1,
#   'density': 1},
#  {'vertices': [670],
#   'fiedler_vals': [-0.020019928794448926],
#   'size': 1,
#   'density': 1},
#  {'vertices': [163, 1314],
#   'fiedler_vals': [-0.019982760205299568, -0.01995832395137337],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1272],
#   'fiedler_vals': [-0.019915376362529824],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2414],
#   'fiedler_vals': [-0.019793400940264615],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2229],
#   'fiedler_vals': [-0.0196719963126259],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2043, 1325],
#   'fiedler_vals': [-0.01961947157702568, -0.019607846137150806],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2797],
#   'fiedler_vals': [-0.01955287389962251],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2029],
#   'fiedler_vals': [-0.019517606534131548],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1910],
#   'fiedler_vals': [-0.019457281416590696],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2944, 2639],
#   'fiedler_vals': [-0.01942964146478052, -0.019423149706137673],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2081, 2182, 2157],
#   'fiedler_vals': [-0.01938686429646033,
#    -0.019363447101521814,
#    -0.019359874353748512],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2587, 2262],
#   'fiedler_vals': [-0.019321831200019637, -0.019300369011290053],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2684, 2442],
#   'fiedler_vals': [-0.019251850488523306, -0.019226506585108303],
#   'size': 2,
#   'density': 1},
#  {'vertices': [419, 1935, 1999, 1244],
#   'fiedler_vals': [-0.01917752345593912,
#    -0.019154146170870537,
#    -0.01914121060349929,
#    -0.019119921663089328],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2412, 5],
#   'fiedler_vals': [-0.019077020928553987, -0.01906600131050102],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1620],
#   'fiedler_vals': [-0.018997139217978416],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2683],
#   'fiedler_vals': [-0.018968238688931518],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1544],
#   'fiedler_vals': [-0.018916481641436958],
#   'size': 1,
#   'density': 1},
#  {'vertices': [513],
#   'fiedler_vals': [-0.01887361464051144],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1616, 1995, 2553],
#   'fiedler_vals': [-0.01880891648964474,
#    -0.01879856601194479,
#    -0.018781064965545973],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1184, 1879],
#   'fiedler_vals': [-0.01869576022322389, -0.018670454739162644],
#   'size': 2,
#   'density': 1},
#  {'vertices': [878],
#   'fiedler_vals': [-0.01863152877116586],
#   'size': 1,
#   'density': 1},
#  {'vertices': [712],
#   'fiedler_vals': [-0.018454267942315295],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1077, 2163, 2607],
#   'fiedler_vals': [-0.018423001079183335,
#    -0.018398788557508126,
#    -0.018395269236963576],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1780],
#   'fiedler_vals': [-0.018357865376148412],
#   'size': 1,
#   'density': 1},
#  {'vertices': [501, 2104, 213, 452],
#   'fiedler_vals': [-0.018324972564620855,
#    -0.01832148709627399,
#    -0.01830290606589131,
#    -0.018301456277345262],
#   'size': 4,
#   'density': 1},
#  {'vertices': [735],
#   'fiedler_vals': [-0.01825306451272658],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1442, 1478, 92, 232, 750, 2633, 1054],
#   'fiedler_vals': [-0.018201769038696025,
#    -0.018201079460505382,
#    -0.01819409574911262,
#    -0.018191370671738233,
#    -0.018173792081487526,
#    -0.018162030185928824,
#    -0.01816190399732382],
#   'size': 7,
#   'density': 1},
#  {'vertices': [1252],
#   'fiedler_vals': [-0.018070926424308464],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1142],
#   'fiedler_vals': [-0.01797932656357378],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2103, 1075, 709, 456],
#   'fiedler_vals': [-0.017902100309739696,
#    -0.01790032742977755,
#    -0.01789614981835254,
#    -0.017894961207068898],
#   'size': 4,
#   'density': 1},
#  {'vertices': [1385],
#   'fiedler_vals': [-0.01781384264886179],
#   'size': 1,
#   'density': 1},
#  {'vertices': [535, 1672],
#   'fiedler_vals': [-0.017780452146770084, -0.01777116732708157],
#   'size': 2,
#   'density': 1},
#  {'vertices': [934],
#   'fiedler_vals': [-0.01773389511511373],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2315, 275, 922],
#   'fiedler_vals': [-0.017666099614193295,
#    -0.017658550610393803,
#    -0.017648206357679188],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2784],
#   'fiedler_vals': [-0.01760976946645622],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2066],
#   'fiedler_vals': [-0.017545058122453206],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1735, 896, 1568],
#   'fiedler_vals': [-0.017443615057407786,
#    -0.017431680982583533,
#    -0.017431122094963128],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2755],
#   'fiedler_vals': [-0.01738041650083011],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1198],
#   'fiedler_vals': [-0.017339234872195144],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1031],
#   'fiedler_vals': [-0.017299034898450492],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2245, 1213, 2796],
#   'fiedler_vals': [-0.017251380020135768,
#    -0.017232067255139687,
#    -0.017209754154740676],
#   'size': 3,
#   'density': 1},
#  {'vertices': [491],
#   'fiedler_vals': [-0.01714141010971424],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1924],
#   'fiedler_vals': [-0.017041870662892606],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1510, 1921],
#   'fiedler_vals': [-0.016983548213013903, -0.016974170509707114],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1146, 2413, 2691],
#   'fiedler_vals': [-0.016943638597322157,
#    -0.01693326579247071,
#    -0.016918662454157515],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2679, 1766, 511, 2210, 1005, 353],
#   'fiedler_vals': [-0.016852519671790345,
#    -0.016848183521251444,
#    -0.016838006119410356,
#    -0.016819738037548323,
#    -0.016818540769336348,
#    -0.01681345891474381],
#   'size': 6,
#   'density': 1},
#  {'vertices': [2813],
#   'fiedler_vals': [-0.01675483244765409],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2943, 879, 1117, 331, 778],
#   'fiedler_vals': [-0.01671688148054401,
#    -0.016705076405991295,
#    -0.01669764566815557,
#    -0.016696631051171636,
#    -0.01667624742702657],
#   'size': 5,
#   'density': 1},
#  {'vertices': [425, 1187, 690, 577, 1324],
#   'fiedler_vals': [-0.016600109370709788,
#    -0.01659952969392203,
#    -0.016579260479774233,
#    -0.016553212590436978,
#    -0.016542522824819432],
#   'size': 5,
#   'density': 1},
#  {'vertices': [2506,
#    1715,
#    188,
#    2682,
#    364,
#    2654,
#    314,
#    1888,
#    1675,
#    660,
#    1950,
#    849,
#    246,
#    2495,
#    156,
#    2159],
#   'fiedler_vals': [-0.01648915061405033,
#    -0.01647621838932297,
#    -0.016473775067892556,
#    -0.016470166762761345,
#    -0.016447489629452826,
#    -0.016424428122145694,
#    -0.016420703448020563,
#    -0.016402392984886046,
#    -0.016399147225004955,
#    -0.01637977049633258,
#    -0.01637301503179827,
#    -0.016366500248486293,
#    -0.01636009857154454,
#    -0.016339232397173716,
#    -0.01631509975485176,
#    -0.016298966340943973],
#   'size': 16,
#   'density': 1},
#  {'vertices': [1574, 1890],
#   'fiedler_vals': [-0.0162143564399453, -0.016199118146298947],
#   'size': 2,
#   'density': 1},
#  {'vertices': [139, 2237],
#   'fiedler_vals': [-0.016157961850650347, -0.016156965453853134],
#   'size': 2,
#   'density': 1},
#  {'vertices': [530, 1370],
#   'fiedler_vals': [-0.016115535183069952, -0.016103019230104796],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2017, 961, 2834, 499],
#   'fiedler_vals': [-0.01605697063296832,
#    -0.016055003897497054,
#    -0.016053469339852727,
#    -0.016046356674743068],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2923],
#   'fiedler_vals': [-0.016003656611012763],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2486, 768],
#   'fiedler_vals': [-0.015931259506320076, -0.01592669552503628],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2298, 1854, 34, 440, 2484, 935, 335, 1344, 1930],
#   'fiedler_vals': [-0.01588259445899391,
#    -0.015869084698855326,
#    -0.01586317065130968,
#    -0.015861396965814487,
#    -0.01583608662743478,
#    -0.015809611661898613,
#    -0.015788462619046838,
#    -0.015782323639437965,
#    -0.01576220127288045],
#   'size': 9,
#   'density': 1},
#  {'vertices': [584, 2658, 1923, 1619],
#   'fiedler_vals': [-0.01572926539591108,
#    -0.015711665728480397,
#    -0.01569953930664291,
#    -0.015681321086104226],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2839, 332],
#   'fiedler_vals': [-0.015652235222441132, -0.01563495928983502],
#   'size': 2,
#   'density': 1},
#  {'vertices': [338, 2700],
#   'fiedler_vals': [-0.015566954968567095, -0.015542026853130803],
#   'size': 2,
#   'density': 1},
#  {'vertices': [733],
#   'fiedler_vals': [-0.015512271118929166],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2748],
#   'fiedler_vals': [-0.015373433874014722],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2102, 1490, 360, 1365, 2064, 1607],
#   'fiedler_vals': [-0.015294284811812895,
#    -0.015275372073690268,
#    -0.015271907930491624,
#    -0.015258324103216574,
#    -0.015251929267244776,
#    -0.015242097948561493],
#   'size': 6,
#   'density': 1},
#  {'vertices': [932],
#   'fiedler_vals': [-0.015143889285525127],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2214, 2253],
#   'fiedler_vals': [-0.01510358550936621, -0.01508474343682792],
#   'size': 2,
#   'density': 1},
#  {'vertices': [828, 2721],
#   'fiedler_vals': [-0.015018796471706326, -0.014996825137845506],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1676, 1654, 1952, 1609, 1206, 1899],
#   'fiedler_vals': [-0.014964581996184792,
#    -0.014951635134009666,
#    -0.0149269382341556,
#    -0.014900356285929936,
#    -0.01488983419255277,
#    -0.014865083932391084],
#   'size': 6,
#   'density': 1},
#  {'vertices': [2905],
#   'fiedler_vals': [-0.014794121342559127],
#   'size': 1,
#   'density': 1},
#  {'vertices': [812],
#   'fiedler_vals': [-0.01467872503366273],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2023, 432, 2101, 2232, 2811, 343, 1734, 1705, 2461, 461, 519],
#   'fiedler_vals': [-0.014606026550056547,
#    -0.01460371864127732,
#    -0.014585573877150424,
#    -0.014584815497334931,
#    -0.01458306169809308,
#    -0.014562202396645156,
#    -0.0145552590511068,
#    -0.014550863587760754,
#    -0.014534064073426936,
#    -0.014531175631200315,
#    -0.014516858736277788],
#   'size': 11,
#   'density': 1},
#  {'vertices': [2309, 405, 189, 2354],
#   'fiedler_vals': [-0.01447213095982161,
#    -0.014446655580203735,
#    -0.014434714690519719,
#    -0.014429522878242342],
#   'size': 4,
#   'density': 1},
#  {'vertices': [229],
#   'fiedler_vals': [-0.014393714422804196],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1223, 1437, 2353, 1790],
#   'fiedler_vals': [-0.014257452358253327,
#    -0.014237337712870354,
#    -0.014226966531214216,
#    -0.014216722268730593],
#   'size': 4,
#   'density': 1},
#  {'vertices': [1543],
#   'fiedler_vals': [-0.014086688297722973],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1599, 2127, 575],
#   'fiedler_vals': [-0.014038800496985986,
#    -0.014021810975973159,
#    -0.013996221642964922],
#   'size': 3,
#   'density': 1},
#  {'vertices': [627, 2754, 1348],
#   'fiedler_vals': [-0.013967828847028428,
#    -0.013950120459152407,
#    -0.013926292100612789],
#   'size': 3,
#   'density': 1},
#  {'vertices': [61, 1218, 1934],
#   'fiedler_vals': [-0.013844315707973539,
#    -0.013843857655416987,
#    -0.013841194782915721],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1416, 2606, 2424],
#   'fiedler_vals': [-0.013788579393490118,
#    -0.013776811456877638,
#    -0.013771248997797653],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1781],
#   'fiedler_vals': [-0.01374146238387441],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2969],
#   'fiedler_vals': [-0.013714527086798423],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1],
#   'fiedler_vals': [-0.013608597020306127],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2812, 1521],
#   'fiedler_vals': [-0.013577547596899456, -0.013575492898313269],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1864, 549],
#   'fiedler_vals': [-0.013501732962040203, -0.013477219863926549],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1327, 839, 1392],
#   'fiedler_vals': [-0.013434931662571896,
#    -0.013432735177869316,
#    -0.013415854698185492],
#   'size': 3,
#   'density': 1},
#  {'vertices': [958, 1070],
#   'fiedler_vals': [-0.013370812988923779, -0.013367794301244927],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1982, 2584, 1394],
#   'fiedler_vals': [-0.013320606309159487,
#    -0.013315501508879056,
#    -0.013298765105473854],
#   'size': 3,
#   'density': 1},
#  {'vertices': [149, 2544, 959, 40],
#   'fiedler_vals': [-0.013249333091299147,
#    -0.01324593101031871,
#    -0.013220413745363695,
#    -0.013220118281718714],
#   'size': 4,
#   'density': 1},
#  {'vertices': [497, 521, 1971],
#   'fiedler_vals': [-0.013187229836702426,
#    -0.01316774444784133,
#    -0.013157227948309648],
#   'size': 3,
#   'density': 1},
#  {'vertices': [264, 1572, 1288, 2034],
#   'fiedler_vals': [-0.013091193311797563,
#    -0.013085302925807289,
#    -0.013075700858071165,
#    -0.013075369033714777],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2250],
#   'fiedler_vals': [-0.01298185956110321],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2634, 98],
#   'fiedler_vals': [-0.012904779771442042, -0.012889333015525415],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1057],
#   'fiedler_vals': [-0.012853750748268939],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2105, 2749, 813, 348, 2662, 2447],
#   'fiedler_vals': [-0.01280530788208184,
#    -0.012799106485344101,
#    -0.01279763028172727,
#    -0.012790587580978077,
#    -0.01278496162147915,
#    -0.01277999127000751],
#   'size': 6,
#   'density': 1},
#  {'vertices': [2791, 1116, 138],
#   'fiedler_vals': [-0.012744132165535299,
#    -0.012727114915559579,
#    -0.012709292233895868],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2458, 587, 2209, 1435],
#   'fiedler_vals': [-0.012664642266731784,
#    -0.012664049852217574,
#    -0.012654950940562992,
#    -0.012630600538164996],
#   'size': 4,
#   'density': 1},
#  {'vertices': [95, 979, 1497, 1032],
#   'fiedler_vals': [-0.012596810694253766,
#    -0.012582079858537237,
#    -0.012577129547070206,
#    -0.012558388793193218],
#   'size': 4,
#   'density': 1},
#  {'vertices': [487],
#   'fiedler_vals': [-0.012516523101795164],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1480, 2098, 344, 949, 316],
#   'fiedler_vals': [-0.012423082793537389,
#    -0.012421564646515514,
#    -0.012399297810469171,
#    -0.012397085568292606,
#    -0.012386153404017306],
#   'size': 5,
#   'density': 1},
#  {'vertices': [941, 722, 2531],
#   'fiedler_vals': [-0.012358316155711232,
#    -0.012337403767169595,
#    -0.012333651053181868],
#   'size': 3,
#   'density': 1},
#  {'vertices': [540,
#    1880,
#    2088,
#    1163,
#    1036,
#    2933,
#    1283,
#    2942,
#    2124,
#    170,
#    1673,
#    2456],
#   'fiedler_vals': [-0.012303843730975473,
#    -0.012298877364849286,
#    -0.01228077902280506,
#    -0.012272490888930001,
#    -0.012271944635686717,
#    -0.012247268593294912,
#    -0.012246061481168783,
#    -0.012233204839497653,
#    -0.012229124578317525,
#    -0.012204414931659364,
#    -0.012202586909232298,
#    -0.012190094370407528],
#   'size': 12,
#   'density': 1},
#  {'vertices': [1161, 317, 1037],
#   'fiedler_vals': [-0.012158114782152632,
#    -0.012145398724677839,
#    -0.012137368098866968],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2719, 1124, 2282],
#   'fiedler_vals': [-0.012103184966932854,
#    -0.012096235599890728,
#    -0.012091506239949645],
#   'size': 3,
#   'density': 1},
#  {'vertices': [292, 1380, 52, 194, 1742, 2200],
#   'fiedler_vals': [-0.012012140804373617,
#    -0.011996072788576694,
#    -0.011991228778695759,
#    -0.011989209865901497,
#    -0.011963467140666822,
#    -0.011960290048723676],
#   'size': 6,
#   'density': 1},
#  {'vertices': [1231, 500],
#   'fiedler_vals': [-0.01192746516751908, -0.011919139458456079],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2222, 1993, 439],
#   'fiedler_vals': [-0.011882300612198126,
#    -0.011861191832790188,
#    -0.01184776920162547],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1307, 1292],
#   'fiedler_vals': [-0.01181961437906849, -0.011794086620335837],
#   'size': 2,
#   'density': 1},
#  {'vertices': [933, 2423, 2783, 1148],
#   'fiedler_vals': [-0.011738969906524777,
#    -0.011731711653619973,
#    -0.011719768989468544,
#    -0.011709626395940862],
#   'size': 4,
#   'density': 1},
#  {'vertices': [420, 351],
#   'fiedler_vals': [-0.011670938753205382, -0.01164692029093178],
#   'size': 2,
#   'density': 1},
#  {'vertices': [904, 825, 1896],
#   'fiedler_vals': [-0.01161747415335575,
#    -0.011615309352504226,
#    -0.011604674840604129],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1515,
#    1305,
#    1595,
#    589,
#    985,
#    2208,
#    1179,
#    1180,
#    2156,
#    214,
#    847,
#    541,
#    2252],
#   'fiedler_vals': [-0.011570680109015899,
#    -0.011563096263304274,
#    -0.011538593492786188,
#    -0.011526129588127517,
#    -0.011500664242394787,
#    -0.011485628560493795,
#    -0.011480789261044785,
#    -0.01147434108891435,
#    -0.011466085060382613,
#    -0.011461932232812538,
#    -0.011457958775373806,
#    -0.011451773918599415,
#    -0.011443776846857025],
#   'size': 13,
#   'density': 1},
#  {'vertices': [2020],
#   'fiedler_vals': [-0.01140494725523969],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2922, 2904],
#   'fiedler_vals': [-0.01137762834592488, -0.011374906942246835],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1895],
#   'fiedler_vals': [-0.011325149695523442],
#   'size': 1,
#   'density': 1},
#  {'vertices': [701],
#   'fiedler_vals': [-0.011286588844604128],
#   'size': 1,
#   'density': 1},
#  {'vertices': [101, 2788],
#   'fiedler_vals': [-0.011231439631568646, -0.011211355196274054],
#   'size': 2,
#   'density': 1},
#  {'vertices': [581, 2618, 1911, 1623, 411, 54],
#   'fiedler_vals': [-0.01117117140542858,
#    -0.011148105650573278,
#    -0.011148063551661404,
#    -0.01113979330518994,
#    -0.011124442906272451,
#    -0.011116441799112234],
#   'size': 6,
#   'density': 1},
#  {'vertices': [1949],
#   'fiedler_vals': [-0.011082773224863472],
#   'size': 1,
#   'density': 1},
#  {'vertices': [649, 2690, 1086, 2640, 2653],
#   'fiedler_vals': [-0.011036990771145542,
#    -0.011021544030902991,
#    -0.011005253196803969,
#    -0.011004973499295018,
#    -0.010991352960958859],
#   'size': 5,
#   'density': 1},
#  {'vertices': [2310],
#   'fiedler_vals': [-0.01093396015181445],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2945, 384],
#   'fiedler_vals': [-0.010891096532442792, -0.01087995853657677],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2395, 2711, 309, 1944, 1538, 994],
#   'fiedler_vals': [-0.010810127860294812,
#    -0.01079809211916735,
#    -0.010782242482262462,
#    -0.01075651141279509,
#    -0.010752114688864906,
#    -0.01075047279265844],
#   'size': 6,
#   'density': 1},
#  {'vertices': [1033, 1887],
#   'fiedler_vals': [-0.010707541827230325, -0.010698778668054685],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2021],
#   'fiedler_vals': [-0.010615310682119048],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1960],
#   'fiedler_vals': [-0.010581700028226827],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2808, 1018],
#   'fiedler_vals': [-0.010530627791950933, -0.010525097238299308],
#   'size': 2,
#   'density': 1},
#  {'vertices': [21],
#   'fiedler_vals': [-0.010490737599967366],
#   'size': 1,
#   'density': 1},
#  {'vertices': [954, 2261, 1118, 749, 1626, 1614, 942, 2233],
#   'fiedler_vals': [-0.010433343956471528,
#    -0.01043059951384744,
#    -0.010418708596081206,
#    -0.010414455588522626,
#    -0.010413746787344498,
#    -0.010396495672699449,
#    -0.010389791030264798,
#    -0.010379797997268136],
#   'size': 8,
#   'density': 1},
#  {'vertices': [2341],
#   'fiedler_vals': [-0.010342904390607349],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1680, 2588],
#   'fiedler_vals': [-0.010299624408573061, -0.010286629081896663],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2026, 603, 175, 1251, 1582, 1104, 2713, 255, 1335],
#   'fiedler_vals': [-0.010217537375613657,
#    -0.010213607825969258,
#    -0.010194862086893075,
#    -0.010190973608408704,
#    -0.010178922885702057,
#    -0.010164103516989549,
#    -0.010149732022354477,
#    -0.010135231927015284,
#    -0.010133465636488618],
#   'size': 9,
#   'density': 1},
#  {'vertices': [833, 645, 412, 956, 2251, 2714],
#   'fiedler_vals': [-0.010095739231692175,
#    -0.010084176569343385,
#    -0.0100638872550537,
#    -0.010061931243629208,
#    -0.010045802783711791,
#    -0.01003057915457031],
#   'size': 6,
#   'density': 1},
#  {'vertices': [1343],
#   'fiedler_vals': [-0.009970064683685663],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1030, 1945, 2396, 895],
#   'fiedler_vals': [-0.009847369153216382,
#    -0.009845352744910156,
#    -0.009844224673107938,
#    -0.009821238616790932],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2638, 1897, 394, 1898, 657],
#   'fiedler_vals': [-0.009746755715382482,
#    -0.009745970173155162,
#    -0.009721919149871815,
#    -0.00970262818125914,
#    -0.009685471986712779],
#   'size': 5,
#   'density': 1},
#  {'vertices': [653],
#   'fiedler_vals': [-0.00963564877837135],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2356],
#   'fiedler_vals': [-0.009572339960307073],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2966],
#   'fiedler_vals': [-0.00954052923240052],
#   'size': 1,
#   'density': 1},
#  {'vertices': [406, 58, 2895],
#   'fiedler_vals': [-0.00950756504949427,
#    -0.009488724181445257,
# ...
#   'size': 1,
#   'density': 1},
#  {'vertices': [1549],
#   'fiedler_vals': [0.02508829912152417],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1230],
#   'fiedler_vals': [0.025136943957719662],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1390],
#   'fiedler_vals': [0.025267097709927425],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1131],
#   'fiedler_vals': [0.02534030686529929],
#   'size': 1,
#   'density': 1},
#  {'vertices': [706, 1363],
#   'fiedler_vals': [0.025392183294427835, 0.025393068045974094],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2930, 2804, 2562, 1209, 1661, 1966],
#   'fiedler_vals': [0.025449877727756948,
#    0.025462035901576374,
#    0.02546584718246481,
#    0.025475299441141276,
#    0.02550108365203084,
#    0.025527321824831754],
#   'size': 6,
#   'density': 1},
#  {'vertices': [243],
#   'fiedler_vals': [0.0256528696623566],
#   'size': 1,
#   'density': 1},
#  {'vertices': [881],
#   'fiedler_vals': [0.02569773084292896],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1560],
#   'fiedler_vals': [0.025743255126382657],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2474],
#   'fiedler_vals': [0.02585066564749719],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2070],
#   'fiedler_vals': [0.02590582493181478],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1554],
#   'fiedler_vals': [0.0259325202851621],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1003],
#   'fiedler_vals': [0.02599624888247998],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1430],
#   'fiedler_vals': [0.02602969395163734],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2858, 894, 1664, 1413],
#   'fiedler_vals': [0.026181325542145653,
#    0.02619944567676932,
#    0.026221154050059887,
#    0.026225702472333183],
#   'size': 4,
#   'density': 1},
#  {'vertices': [1294, 930],
#   'fiedler_vals': [0.026276112423639288, 0.026281821738995997],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1692],
#   'fiedler_vals': [0.0263379802899473],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2880],
#   'fiedler_vals': [0.026367297775700856],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1784],
#   'fiedler_vals': [0.026585219454884807],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2706, 1913, 1376, 2879],
#   'fiedler_vals': [0.026616289633163166,
#    0.026639334876550475,
#    0.02665488113885751,
#    0.02666876761772296],
#   'size': 4,
#   'density': 1},
#  {'vertices': [2727, 2996, 2057],
#   'fiedler_vals': [0.02675278017623884,
#    0.026771689890255756,
#    0.026789147470739814],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2824],
#   'fiedler_vals': [0.026827330854531983],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1597],
#   'fiedler_vals': [0.026931595405834806],
#   'size': 1,
#   'density': 1},
#  {'vertices': [261],
#   'fiedler_vals': [0.026964264039376185],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1072, 2568],
#   'fiedler_vals': [0.026996725093983483, 0.02701534786963876],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1683],
#   'fiedler_vals': [0.027043322572683055],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1776],
#   'fiedler_vals': [0.027307350857249595],
#   'size': 1,
#   'density': 1},
#  {'vertices': [474],
#   'fiedler_vals': [0.027345947834921343],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2345, 2039, 2954],
#   'fiedler_vals': [0.02745234020437506,
#    0.027474973321601797,
#    0.027478750377793074],
#   'size': 3,
#   'density': 1},
#  {'vertices': [981],
#   'fiedler_vals': [0.027522553358388175],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2436],
#   'fiedler_vals': [0.02756148388813899],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1689, 1536, 857, 1718],
#   'fiedler_vals': [0.027595050228853547,
#    0.027597495128278547,
#    0.027606021112889737,
#    0.027610711608949626],
#   'size': 4,
#   'density': 1},
#  {'vertices': [472],
#   'fiedler_vals': [0.027646285394465266],
#   'size': 1,
#   'density': 1},
#  {'vertices': [780, 1535],
#   'fiedler_vals': [0.0276854514092813, 0.02768963299459673],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1470, 1565, 2392],
#   'fiedler_vals': [0.02772639225338993,
#    0.027741642560504206,
#    0.027745059060872056],
#   'size': 3,
#   'density': 1},
#  {'vertices': [504],
#   'fiedler_vals': [0.02777578745761967],
#   'size': 1,
#   'density': 1},
#  {'vertices': [19],
#   'fiedler_vals': [0.027824158585470476],
#   'size': 1,
#   'density': 1},
#  {'vertices': [81],
#   'fiedler_vals': [0.02796173337655011],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2197, 110],
#   'fiedler_vals': [0.027991970982738344, 0.02800273318525622],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1537, 2374],
#   'fiedler_vals': [0.028059916514667403, 0.02806581994342885],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2037, 1262],
#   'fiedler_vals': [0.028092752789509675, 0.028101390352461127],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2958],
#   'fiedler_vals': [0.028215535773659806],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2449, 2373],
#   'fiedler_vals': [0.02833489424143486, 0.028349300137726817],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1505],
#   'fiedler_vals': [0.02845143646209812],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1071, 2265, 858],
#   'fiedler_vals': [0.028484814821510544,
#    0.028491122709839237,
#    0.02850735203812086],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2435, 2009, 1449],
#   'fiedler_vals': [0.028623135016001503,
#    0.028624700770811848,
#    0.028633443871577565],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2393],
#   'fiedler_vals': [0.028948620721384703],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2466, 2623, 705],
#   'fiedler_vals': [0.028996661774258223,
#    0.02901205808955455,
#    0.02901863886388079],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2742],
#   'fiedler_vals': [0.029087023260436995],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2000],
#   'fiedler_vals': [0.029126370140656645],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2899],
#   'fiedler_vals': [0.029253012446956363],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2823],
#   'fiedler_vals': [0.029285618355332242],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2995],
#   'fiedler_vals': [0.029357074732665096],
#   'size': 1,
#   'density': 1},
#  {'vertices': [258],
#   'fiedler_vals': [0.029391129291963424],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1644],
#   'fiedler_vals': [0.02947468586428546],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1834],
#   'fiedler_vals': [0.029529864915129194],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2285, 2473],
#   'fiedler_vals': [0.029622373836890932, 0.02964170482450041],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1827, 2820, 1634],
#   'fiedler_vals': [0.02974682946690153,
#    0.02975422548825876,
#    0.029766872445347148],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1211, 2822, 2327],
#   'fiedler_vals': [0.029836278429138028,
#    0.029856077171894584,
#    0.02986224872651329],
#   'size': 3,
#   'density': 1},
#  {'vertices': [691],
#   'fiedler_vals': [0.029894988132111222],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2038],
#   'fiedler_vals': [0.03024203036801706],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2622],
#   'fiedler_vals': [0.030397391797576688],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2317, 1604, 2320],
#   'fiedler_vals': [0.030524607756924577,
#    0.030545460449732966,
#    0.0305569477974546],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1792, 2010],
#   'fiedler_vals': [0.0306146245160049, 0.03061622067473745],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1826, 2774, 2198],
#   'fiedler_vals': [0.030746089748973478,
#    0.03074895046112579,
#    0.030763608267274308],
#   'size': 3,
#   'density': 1},
#  {'vertices': [1690],
#   'fiedler_vals': [0.03080179019504163],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2196],
#   'fiedler_vals': [0.030957639431937096],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2729],
#   'fiedler_vals': [0.031111645495943998],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2979],
#   'fiedler_vals': [0.03133223367484467],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2821],
#   'fiedler_vals': [0.03146292013310932],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2319],
#   'fiedler_vals': [0.031657274749124456],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1200],
#   'fiedler_vals': [0.03180122716930775],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2321, 471],
#   'fiedler_vals': [0.03184132399305877, 0.03184187684881912],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1697, 2728],
#   'fiedler_vals': [0.03204995812844791, 0.032052880162423886],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2006],
#   'fiedler_vals': [0.032193400975960844],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2347],
#   'fiedler_vals': [0.03224109833947796],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2078],
#   'fiedler_vals': [0.03227634994996429],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2869],
#   'fiedler_vals': [0.03241124505412815],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1239],
#   'fiedler_vals': [0.032507549187017544],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2779, 2176, 2955],
#   'fiedler_vals': [0.03270540480938688,
#    0.032723498817557845,
#    0.03273667970158325],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2178, 1472],
#   'fiedler_vals': [0.032776080602793765, 0.032777993445992706],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2771],
#   'fiedler_vals': [0.03282375045601589],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2744],
#   'fiedler_vals': [0.03313865593766854],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2803],
#   'fiedler_vals': [0.033382734480228465],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2850],
#   'fiedler_vals': [0.033674643421031776],
#   'size': 1,
#   'density': 1},
#  {'vertices': [228],
#   'fiedler_vals': [0.03376756179032722],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2760],
#   'fiedler_vals': [0.03381086895374294],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2802],
#   'fiedler_vals': [0.034070172839609156],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1404],
#   'fiedler_vals': [0.03418764623262352],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2394],
#   'fiedler_vals': [0.03433372176620531],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2346, 2956],
#   'fiedler_vals': [0.034455200736977436, 0.034471105572536874],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1711],
#   'fiedler_vals': [0.03469261130060128],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2819],
#   'fiedler_vals': [0.034815919310670504],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1841],
#   'fiedler_vals': [0.034933333431529906],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1712, 2056],
#   'fiedler_vals': [0.03502897611645706, 0.03504101881914707],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2981, 1559],
#   'fiedler_vals': [0.03526396818441953, 0.03526916365779612],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2871],
#   'fiedler_vals': [0.03530379718595899],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2762],
#   'fiedler_vals': [0.035419332835522836],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1469],
#   'fiedler_vals': [0.0354684903733145],
#   'size': 1,
#   'density': 1},
#  {'vertices': [744],
#   'fiedler_vals': [0.03560063647647159],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2870],
#   'fiedler_vals': [0.03574428135646184],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2177],
#   'fiedler_vals': [0.03581374580849556],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2508],
#   'fiedler_vals': [0.03585840034779854],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2980],
#   'fiedler_vals': [0.03593435023724731],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2770],
#   'fiedler_vals': [0.035996238503926074],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1764],
#   'fiedler_vals': [0.036078885484105865],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2538],
#   'fiedler_vals': [0.03618993145411487],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2005, 205],
#   'fiedler_vals': [0.036360640599516054, 0.03637550033838746],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1299],
#   'fiedler_vals': [0.036444618123614686],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1628],
#   'fiedler_vals': [0.03657643870584693],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2075],
#   'fiedler_vals': [0.036611512079221815],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1835],
#   'fiedler_vals': [0.03665341299786932],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2509],
#   'fiedler_vals': [0.03680520066287104],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2454],
#   'fiedler_vals': [0.0368844594875921],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2318],
#   'fiedler_vals': [0.03697192631364335],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2426, 2743],
#   'fiedler_vals': [0.0370239949149246, 0.03704105103214018],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1567],
#   'fiedler_vals': [0.037083160044457136],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2453],
#   'fiedler_vals': [0.03712673063543023],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1842, 2002, 1691],
#   'fiedler_vals': [0.03775333268495298,
#    0.03777740102875373,
#    0.03778722455948956],
#   'size': 3,
#   'density': 1},
#  {'vertices': [2539],
#   'fiedler_vals': [0.03798459104606693],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2761],
#   'fiedler_vals': [0.03816983201392122],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2705],
#   'fiedler_vals': [0.038271732148029654],
#   'size': 1,
#   'density': 1},
#  {'vertices': [716],
#   'fiedler_vals': [0.0385473891357205],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1410],
#   'fiedler_vals': [0.03858897451683402],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2001],
#   'fiedler_vals': [0.0386803478312052],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2437],
#   'fiedler_vals': [0.03921518970255764],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2302],
#   'fiedler_vals': [0.03944032154501072],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2957],
#   'fiedler_vals': [0.03952060030773808],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2450],
#   'fiedler_vals': [0.03985671946610466],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2537, 2300],
#   'fiedler_vals': [0.039914713997372626, 0.039919465854772775],
#   'size': 2,
#   'density': 1},
#  {'vertices': [1698],
#   'fiedler_vals': [0.04037847111903919],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2284],
#   'fiedler_vals': [0.0406097287351347],
#   'size': 1,
#   'density': 1},
#  {'vertices': [779],
#   'fiedler_vals': [0.04063737810613423],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2739],
#   'fiedler_vals': [0.04079771132606762],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2775],
#   'fiedler_vals': [0.04119981241566849],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2427],
#   'fiedler_vals': [0.04146613243741082],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1771],
#   'fiedler_vals': [0.04160668139631679],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2778],
#   'fiedler_vals': [0.04171804592724526],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1779],
#   'fiedler_vals': [0.042595458499810404],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2451],
#   'fiedler_vals': [0.04319325782828983],
#   'size': 1,
#   'density': 1},
#  {'vertices': [1471, 2077],
#   'fiedler_vals': [0.043324474801472716, 0.04334822467357174],
#   'size': 2,
#   'density': 1},
#  {'vertices': [2738],
#   'fiedler_vals': [0.043379506062944245],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2439],
#   'fiedler_vals': [0.04345055177839413],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2704],
#   'fiedler_vals': [0.0440773176157891],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2452],
#   'fiedler_vals': [0.04468125984505609],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2777],
#   'fiedler_vals': [0.04577475394629596],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2076],
#   'fiedler_vals': [0.04589783336232092],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2467],
#   'fiedler_vals': [0.046543401717081954],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2438],
#   'fiedler_vals': [0.047500916326094],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2301],
#   'fiedler_vals': [0.04824998841230623],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2736],
#   'fiedler_vals': [0.048482202422848376],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2776],
#   'fiedler_vals': [0.05047146632771625],
#   'size': 1,
#   'density': 1},
#  {'vertices': [2737],
#   'fiedler_vals': [0.05317281543004248],
#   'size': 1,
#   'density': 1}]
